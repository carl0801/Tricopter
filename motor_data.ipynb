# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
#Read the csv files and store them in a dataframe
m1_7v_r =     pd.read_csv('data/Motor1-RPM-7v.csv')
m1_9v_r =     pd.read_csv('data/Motor1-RPM-9v.csv')
m1_11v_r =    pd.read_csv('data/Motor1-RPM-11v.csv')
m2_7v_r =     pd.read_csv('data/Motor2-RPM-7v.csv')
m2_9v_r =     pd.read_csv('data/Motor2-RPM-9v.csv')
m2_11v_r =    pd.read_csv('data/Motor2-RPM-11v.csv')
m3_7v_r =     pd.read_csv('data/Motor3-RPM-7v.csv')
m3_9v_r =     pd.read_csv('data/Motor3-RPM-9v.csv')
m3_11v_r =    pd.read_csv('data/Motor3-RPM-11v.csv')

# %%
# delete last row of each dataframe
m1_7v = m1_7v_r.copy()[:-1]
m1_9v = m1_9v_r.copy()[:-1]
m1_11v = m1_11v_r.copy()[:-1]
m2_7v = m2_7v_r.copy()[:-1]
m2_9v = m2_9v_r.copy()[:-1]
m2_11v = m2_11v_r.copy()[:-1]
m3_7v = m3_7v_r.copy()[:-1]
m3_9v = m3_9v_r.copy()[:-1]
m3_11v = m3_11v_r.copy()[:-1]

# %%
m3_11v.head(10)
# Out:
#    PWM_Strength  Voltage  Weight1(g)
# 0           0.0    11.07       -1.02
# 1          20.0    11.07       -1.04
# 2          40.0    11.09      -24.43
# 3          60.0    10.71      -80.47
# 4          80.0    11.73     -154.18
# 5         100.0    11.03     -231.58
# 6         120.0     9.58     -300.96
# 7           0.0    11.87     -363.14

# %%
m1_amp_rpm_7v = [
[0.0, 0],
[0.1, 1086],
[0.3, 2102],
[0.9, 3037],
[1.8, 3852],
[3.0, 4567],
[4.4, 5145]
]

m1_amp_rpm_9v = [
[0.0, 0],
[0.1, 1314],
[0.5, 2592],
[1.2, 3703],
[2.4, 4647],
[4.3, 5435],
[6.1, 5989]
]

m1_amp_rpm_11v = [
[0.0, 0],
[0.1,	1592],
[0.7,	3100],
[1.6,	4334],
[3.3,	5390],
[5.5,	6150],
[7.8,	6710]
]

m2_amp_rpm_7v = [
[0.0, 0],
[0.1,	1152],
[0.3,	2161],
[0.8,	3014],
[1.7,	3930],
[2.9,	4673],
[4.3,	5265]
]

m2_amp_rpm_9v = [
[0.0, 0],
[0.2,	1414],
[0.5,	2665],
[1.2,	3790],
[2.4,	4731],
[4.1,	5570],
[6.0,	6190]
]

m2_amp_rpm_11v = [
[0.0, 0],
[0.2,	1685],
[0.6,	3184],
[1.6,	4463],
[3.2,	5509],
[5.2,	6320],
[7.7,	6850]
]

m3_amp_rpm_7v = [
[0.0, 0],
[0.1,	1207],
[0.3,	2156],
[0.9,	3044],
[1.7,	3836],
[2.8,	4500],
[4.2,	5088]
]

m3_amp_rpm_9v = [
[0.0, 0],
[0.1,	1518],
[0.5,	2704],
[1.3,	3757],
[2.4,	4646],
[4.1,	5416],
[6.0,	6020]
]

m3_amp_rpm_11v = [
[0.0, 0],
[0.2,	1802],
[0.7,	3199],
[1.7,	4374],
[3.3,	5357],
[5.3,	6361],
[7.7,	6721]
]

# %%
m1_pre = pd.concat([m1_7v, m1_9v, m1_11v], ignore_index=True)
m2_pre = pd.concat([m2_7v, m2_9v, m2_11v], ignore_index=True)
m3_pre = pd.concat([m3_7v, m3_9v, m3_11v], ignore_index=True)

m1_amp_rpm = pd.DataFrame(m1_amp_rpm_7v + m1_amp_rpm_9v + m1_amp_rpm_11v, columns=['Amp', 'RPM'])
m2_amp_rpm = pd.DataFrame(m2_amp_rpm_7v + m2_amp_rpm_9v + m2_amp_rpm_11v, columns=['Amp', 'RPM'])
m3_amp_rpm = pd.DataFrame(m3_amp_rpm_7v + m3_amp_rpm_9v + m3_amp_rpm_11v, columns=['Amp', 'RPM'])

m1 = pd.concat([m1_pre, m1_amp_rpm], axis=1)
m2 = pd.concat([m2_pre, m2_amp_rpm], axis=1)
m3 = pd.concat([m3_pre, m3_amp_rpm], axis=1)

# %%
m1.head(30)
# Out:
#     PWM_Strength  Voltage  Weight1(g)  Amp   RPM
# 0            0.0     7.02       -3.01  0.0     0
# 1           20.0     7.02       -3.50  0.1  1086
# 2           40.0     7.02      -19.43  0.3  2102
# 3           60.0     7.00      -46.57  0.9  3037
# 4           80.0     6.90      -85.09  1.8  3852
# 5          100.0     7.10     -127.93  3.0  4567
# 6          120.0     6.45     -176.23  4.4  5145
# 7            0.0     9.03       -2.95  0.0     0
# 8           20.0     9.03       -5.08  0.1  1314
# 9           40.0     8.66      -26.86  0.5  2592
# 10          60.0     8.82      -69.52  1.2  3703
# 11          80.0     8.90     -128.29  2.4  4647
# 12         100.0     9.36     -193.59  4.3  5435
# 13         120.0     8.41     -257.14  6.1  5989
# 14           0.0    11.07       -0.46  0.0     0
# 15          20.0    11.05        0.52  0.1  1592
# 16          40.0    11.07      -16.55  0.7  3100
# 17          60.0    11.12      -69.31  1.6  4334
# 18          80.0    10.85     -140.80  3.3  5390
# 19         100.0    10.91     -227.82  5.5  6150
# 20         120.0    11.16     -290.58  7.8  6710

# %%
data1 = m1.copy()
data2 = m2.copy()
data3 = m3.copy()

# print column names in data
print(data1.columns)
# Out:
# Index(['PWM_Strength', 'Voltage', 'Weight1(g)', 'Amp', 'RPM'], dtype='object')

# %%
data1.head(20)
# Out:
#     PWM_Strength  Voltage  Weight1(g)  Amp   RPM
# 0            0.0     7.02       -3.01  0.0     0
# 1           20.0     7.02       -3.50  0.1  1086
# 2           40.0     7.02      -19.43  0.3  2102
# 3           60.0     7.00      -46.57  0.9  3037
# 4           80.0     6.90      -85.09  1.8  3852
# 5          100.0     7.10     -127.93  3.0  4567
# 6          120.0     6.45     -176.23  4.4  5145
# 7            0.0     9.03       -2.95  0.0     0
# 8           20.0     9.03       -5.08  0.1  1314
# 9           40.0     8.66      -26.86  0.5  2592
# 10          60.0     8.82      -69.52  1.2  3703
# 11          80.0     8.90     -128.29  2.4  4647
# 12         100.0     9.36     -193.59  4.3  5435
# 13         120.0     8.41     -257.14  6.1  5989
# 14           0.0    11.07       -0.46  0.0     0
# 15          20.0    11.05        0.52  0.1  1592
# 16          40.0    11.07      -16.55  0.7  3100
# 17          60.0    11.12      -69.31  1.6  4334
# 18          80.0    10.85     -140.80  3.3  5390
# 19         100.0    10.91     -227.82  5.5  6150

# %%
from sklearn.linear_model import LinearRegression

def thrust_model(data, plot=False, motor_number=9):
    # for m1 create column with pwm^2
    data['PWM^2'] = data['PWM_Strength']**2
    # create column with thrust in newtons instead of grams
    data['Thrust'] = (data['Weight1(g)']*-1) * 0.00980665

    # Separate features (X) and target variable (y)
    X = data[['PWM^2', 'Voltage']]
    y = data['Thrust']

    # Create and fit the model
    model = LinearRegression(positive=True)
    model.fit(X, y)

    # Print the coefficients and intercept
    print('Intercept:', model.intercept_)
    print('Coefficients:', model.coef_)

    b = model.intercept_
    a1 = model.coef_[0]
    a2 = model.coef_[1]

    if plot == True:
        # draw a 3d scatter plot of the data points and the regression plane
        fig = plt.figure()
        ax = fig.add_subplot(111, projection='3d')
        ax.scatter(data['PWM^2'], data['Voltage'], data['Thrust'], c='r', marker='o')
        # draw the regression plane
        x = np.linspace(data['PWM^2'].min(), data['PWM^2'].max(), 100)
        y = np.linspace(data['Voltage'].min(), data['Voltage'].max(), 100)
        x, y = np.meshgrid(x, y)
        z = model.intercept_ + model.coef_[0] * x + model.coef_[1] * y
        ax.plot_surface(x, y, z, alpha=0.5)

        ax.set_xlabel('PWM^2')
        ax.set_ylabel('Voltage')
        ax.set_zlabel('Thrust')
        ax.set_title('Motor ' + str(motor_number))
        plt.show()

    return b, a1, a2

# %%
m1_b, m1_a1, m1_a2 = thrust_model(data1, motor_number=1)
m2_b, m2_a1, m2_a2 = thrust_model(data2, motor_number=2)
m3_b, m3_a1, m3_a2 = thrust_model(data3, motor_number=3)
# Out:
# Intercept: -0.8974464842321774
# Coefficients: [0.00017223 0.09883168]
# Intercept: -1.2314400221799555
# Coefficients: [0.00016446 0.13414214]
# Intercept: -1.8423526887156998
# Coefficients: [1.41527126e-04 2.31814140e-01]

# %%
pwm = 1
voltage = 10

thrust_1 = m1_b + m1_a1 * pwm**2 + m1_a2 * voltage
thrust_2 = m2_b + m2_a1 * pwm**2 + m2_a2 * voltage
thrust_3 = m3_b + m3_a1 * pwm**2 + m3_a2 * voltage

print('Thrust for motor 1:', thrust_1)
print('Thrust for motor 2:', thrust_2)
print('Thrust for motor 3:', thrust_3)
print()
print("Thrust equations:")
print("thrust_m1 = {:.9f} + {:.9f} * pwm**2 + {:.9f} * voltage".format(m1_b, m1_a1, m1_a2))
print("thrust_m2 = {:.9f} + {:.9f} * pwm**2 + {:.9f} * voltage".format(m2_b, m2_a1, m2_a2))
print("thrust_m3 = {:.9f} + {:.9f} * pwm**2 + {:.9f} * voltage".format(m3_b, m3_a1, m3_a2))
# Out:
# Thrust for motor 1: 0.09104253729188194
# Thrust for motor 2: 0.11014587647366358
# Thrust for motor 3: 0.4759302372945078
#
# Thrust equations:
# thrust_m1 = -0.897446484 + 0.000172229 * pwm**2 + 0.098831679 * voltage
# thrust_m2 = -1.231440022 + 0.000164455 * pwm**2 + 0.134142144 * voltage
# thrust_m3 = -1.842352689 + 0.000141527 * pwm**2 + 0.231814140 * voltage

# %%
thrust_m1 = -0.897446484 + 0.000172229 * pwm**2 + 0.098831679 * voltage
thrust_m2 = -1.231440022 + 0.000164455 * pwm**2 + 0.134142144 * voltage
thrust_m3 = -1.842352689 + 0.000141527 * pwm**2 + 0.231814140 * voltage

# %%
pwm = 120.0
voltage = 11

thrust_m1 = -0.897446484 + 0.000172229 * pwm**2 + 0.098831679 * voltage
thrust_m2 = -1.231440022 + 0.000164455 * pwm**2 + 0.134142144 * voltage
thrust_m3 = -1.842352689 + 0.000141527 * pwm**2 + 0.231814140 * voltage

print('Thrust for motor 1: ', thrust_m1)
print('Thrust for motor 2: ', thrust_m2)
print('Thrust for motor 3: ', thrust_m3)
# Out:
# Thrust for motor 1:  2.6697995850000003
# Thrust for motor 2:  2.612275562
# Thrust for motor 3:  2.745591651

# %%
from sklearn.preprocessing import PolynomialFeatures

def thrust_model(data, plot=False, motor_number=9):
    # for m1 create column with pwm^2
    data['PWM^2'] = data['PWM_Strength']**2
    # create column with thrust in newtons instead of grams
    data['Thrust'] = (data['Weight1(g)']*-1) * 0.00980665

    # Separate features (X) and target variable (y)
    X = data[['PWM^2', 'Voltage']]
    y = data['Thrust']

    # Create and fit the model
    model = PolynomialFeatures()
    model.fit(X, y)

    # Print the coefficients
    

    b = model.intercept_
    a1 = model.coef_[0]
    a2 = model.coef_[1]

    if plot == True:
        # draw a 3d scatter plot of the data points and the regression plane
        fig = plt.figure()
        ax = fig.add_subplot(111, projection='3d')
        ax.scatter(data['PWM^2'], data['Voltage'], data['Thrust'], c='r', marker='o')
        # draw the regression plane
        x = np.linspace(data['PWM^2'].min(), data['PWM^2'].max(), 100)
        y = np.linspace(data['Voltage'].min(), data['Voltage'].max(), 100)
        x, y = np.meshgrid(x, y)
        z = model.intercept_ + model.coef_[0] * x + model.coef_[1] * y
        ax.plot_surface(x, y, z, alpha=0.5)

        ax.set_xlabel('PWM^2')
        ax.set_ylabel('Voltage')
        ax.set_zlabel('Thrust')
        ax.set_title('Motor ' + str(motor_number))
        plt.show()

    return b, a1, a2

# %%
data = m1.copy()

# create column with pwm^2
data['PWM^2'] = data['PWM_Strength']**2
# create column with thrust in newtons instead of grams
data['Thrust'] = (data['Weight1(g)']*-1) * 0.00980665

# air density
rho = 1.204

# propeller diameter
D = 0.2032

# thrust coefficient
kt = 6.769e-6

# create new column with calculated RPM values from thrust coefficient, air density, propeller diameter and thrust
data['RPS'] = data['Thrust']**(1/2)/(D**2*kt**(1/2)*rho**(1/2))
data['RPM'] = data['RPS']*60

# %%
data.head(20)
# Out:
#     PWM_Strength  Voltage  Weight1(g)    PWM^2    Thrust           RPS  \
# 0            0.0     7.02       -3.01      0.0  0.029518   1457.540657
# 1           20.0     7.02       -3.50    400.0  0.034323   1571.706511
# 2           40.0     7.02      -19.43   1600.0  0.190543   3703.171542
# 3           60.0     7.00      -46.57   3600.0  0.456696   5733.113623
# 4           80.0     6.90      -85.09   6400.0  0.834448   7749.553697
# 5          100.0     7.10     -127.93  10000.0  1.254565   9502.188248
# 6          120.0     6.45     -176.23  14400.0  1.728226  11152.631448
# 7            0.0     6.31     -219.51      0.0  2.152658  12446.997002
# 8            0.0     9.03       -2.95      0.0  0.028930   1442.940549
# 9           20.0     9.03       -5.08    400.0  0.049818   1893.517338
# 10          40.0     8.66      -26.86   1600.0  0.263407   4354.020146
# 11          60.0     8.82      -69.52   3600.0  0.681758   7004.744708
# 12          80.0     8.90     -128.29   6400.0  1.258095   9515.548620
# 13         100.0     9.36     -193.59  10000.0  1.898469  11689.041216
# 14         120.0     8.41     -257.14  14400.0  2.521682  13471.695249
# 15           0.0     8.04     -307.00      0.0  3.010642  14719.959591
# 16           0.0    11.07       -0.46      0.0  0.004511    569.791998
# 17          20.0    11.05        0.52    400.0 -0.005099           NaN
# 18          40.0    11.07      -16.55   1600.0  0.162300   3417.719601
# 19          60.0    11.12      -69.31   3600.0  0.679699   6994.157043
#
#               RPM
# 0    87452.439407
# 1    94302.390646
# 2   222190.292529
# 3   343986.817379
# 4   464973.221846
# 5   570131.294900
# 6   669157.886893
# 7   746819.820099
# 8    86576.432954
# 9   113611.040307
# 10  261241.208782
# 11  420284.682461
# 12  570932.917176
# 13  701342.472950
# 14  808301.714938
# 15  883197.575479
# 16   34187.519885
# 17            NaN
# 18  205063.176043
# 19  419649.422565

# %%
data.tail(20)
# Out:
#      PWM_Strength  Voltage  Weight1(g)    PWM^2    Thrust           RPS  \
# 470         102.0    10.21     -375.16  10404.0  3.679063  16132.099528
# 471         103.0    12.69     -379.26  10609.0  3.719270  16220.011191
# 472         104.0    12.41     -382.92  10816.0  3.755162  16298.087845
# 473         105.0    12.45     -386.36  11025.0  3.788897  16371.131911
# 474         106.0     9.87     -388.44  11236.0  3.809295  16415.140410
# 475         107.0    10.13     -393.11  11449.0  3.855092  16513.520692
# 476         108.0    10.89     -396.00  11664.0  3.883433  16574.110201
# 477         109.0    12.49     -407.30  11881.0  3.994249  16808.920928
# 478         110.0    11.05     -405.93  12100.0  3.980813  16780.627755
# 479         111.0    12.32     -408.73  12321.0  4.008272  16838.402510
# 480         112.0    11.46     -410.21  12544.0  4.022786  16868.860657
# 481         113.0    12.22     -411.96  12769.0  4.039948  16904.804550
# 482         114.0    11.83     -414.85  12996.0  4.068289  16963.996586
# 483         115.0    10.22     -419.04  13225.0  4.109379  17049.449847
# 484         116.0    12.22     -423.37  13456.0  4.151841  17137.310658
# 485         117.0    13.65     -425.28  13689.0  4.170572  17175.923962
# 486         118.0    10.28     -427.97  13924.0  4.196952  17230.159294
# 487         119.0     9.56     -439.56  14161.0  4.310611  17461.908634
# 488           0.0    12.32     -435.36      0.0  4.269423  17378.284044
# 489           1.0    12.04     -165.86      1.0  1.626531  10726.386945
#
#               RPM
# 470  9.679260e+05
# 471  9.732007e+05
# 472  9.778853e+05
# 473  9.822679e+05
# 474  9.849084e+05
# 475  9.908112e+05
# 476  9.944466e+05
# 477  1.008535e+06
# 478  1.006838e+06
# 479  1.010304e+06
# 480  1.012132e+06
# 481  1.014288e+06
# 482  1.017840e+06
# 483  1.022967e+06
# 484  1.028239e+06
# 485  1.030555e+06
# 486  1.033810e+06
# 487  1.047715e+06
# 488  1.042697e+06
# 489  6.435832e+05
